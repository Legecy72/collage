# %%
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import layers, models

# %%
# 1. Load CIFAR10 Dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 87s 1us/step

# %%
# 2. Resize images
x_train_resized = tf.image.resize(x_train, (96, 96))
x_test_resized  = tf.image.resize(x_test, (96, 96))

# %%
# 3. Load Pretrained Model
base_model = MobileNetV2(
    weights='imagenet',
    include_top=False,
    input_shape=(96,96,3)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_96_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
# 4. Freeze
base_model.trainable = True

for layer in base_model.layers[:-20]:
    layer.trainable = False

# %%
# 5. Modify Architecture
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(10, activation='softmax')
])

# %%
# 6. Compile (Fine-Tuning)
model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-5),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# 7. Training
model.fit(
    x_train_resized,
    y_train,
    epochs=5,
    validation_data=(x_test_resized, y_test)
)
# Out:
# Epoch 1/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 203s 122ms/step - accuracy: 0.4911 - loss: 1.4837 - val_accuracy: 0.7543 - val_loss: 0.7109
# Epoch 2/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 202s 129ms/step - accuracy: 0.7670 - loss: 0.6838 - val_accuracy: 0.7927 - val_loss: 0.5916
# Epoch 3/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 193s 123ms/step - accuracy: 0.8029 - loss: 0.5695 - val_accuracy: 0.8118 - val_loss: 0.5440
# Epoch 4/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 211s 135ms/step - accuracy: 0.8321 - loss: 0.4931 - val_accuracy: 0.8254 - val_loss: 0.5133
# Epoch 5/5
# 1080/1563 ━━━━━━━━━━━━━━━━━━━━ 57s 119ms/step - accuracy: 0.8523 - loss: 0.4282
